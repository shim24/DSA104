# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("iarunava/cell-images-for-detecting-malaria")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\jschoer\.cache\kagglehub\datasets\iarunava\cell-images-for-detecting-malaria\1.archive...
# 100%|██████████| 675M/675M [09:10<00:00, 1.29MB/s]
# Extracting files...
# Path to dataset files: C:\Users\jschoer\.cache\kagglehub\datasets\iarunava\cell-images-for-detecting-malaria\versions\1
